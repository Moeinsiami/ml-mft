# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree

data = {
    "hour": [6, 8, 3, 1, 7, 2, 5, 4],
    "present": [1, 1, 1, 0, 1, 0, 1, 1],
    "status": ["pass", "pass", "pass", "fail", "pass", "fail", "pass", "pass"]
}

df = pd.DataFrame(data)

x = df[["hour", "present"]]
y = df["status"]

model = DecisionTreeClassifier(criterion="entropy", random_state=0)
model.fit(x, y)

plt.figure(figsize=(10, 6))
plot_tree(model, feature_names=x.columns, class_names=model.classes_, filled=True)
plt.show()

sample = [5, 1]
predict = model.predict([sample])
print(predict)
# Out:
# ['pass']
# C:\Users\aa\anaconda3\envs\dataenv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
